# %% [markdown]
# # SQL-based attribution scoring
#
# This notebook builds a Hive query that attributes conversions to model features
#
# Inputs:
#
# * JSON model spec
# * DB location

# %%
from __future__ import print_function, division
# %matplotlib inline
from hive_query import hive_query
import json

# %% [markdown]
# ## Setup

# %%
model_json = 'Model_modeldate=1970-01-01,modeldim=bindp045.JSON'
stack = 'coeffstack_nwi_autotax3_mspnwi_nwi.coeffstack_base'
db = 'joao'
attr_stack = 'tmp_nwi_attr_stack'

# %% [markdown]
# ## Extraction of model features

# %%
with open(model_json, 'r') as f:
    model = json.load(f)

all_features = model[u'ModelVarList']
all_features
# Out:
# [{u'AdditiveEventMetrics': [],
#   u'Group': u'',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': -10.119515031874899,
#   u'ModelVarIsDerived': u'0',
#   u'ModelVarMktgFlag': u'0',
#   u'ModelVarName': u'Intercept',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'0',
#   u'coeffLBound': u'-100000',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'0',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_count_event_all_w45'],
#   u'Group': u'event_all',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': u'',
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'1',
#   u'ModelVarName': u'stackmetric_count_event_all_w45',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'stackmetric_count_event_all_w45',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'1',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_numads30_event_0_im_w45'],
#   u'Group': u'event_0_im',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': u'',
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'1',
#   u'ModelVarName': u'transvar_log_numads30_event_0_im_w45',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_numads30_event_0_im_w45)',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'1',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_num_event_1_cl_w45'],
#   u'Group': u'event_1_cl',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': 0.149208929329371,
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'1',
#   u'ModelVarName': u'transvar_log_num_event_1_cl_w45',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_num_event_1_cl_w45)',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'0',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_num_event_0_cl_w45'],
#   u'Group': u'event_0_cl',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': 0.546911058329205,
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'1',
#   u'ModelVarName': u'transvar_log_num_event_0_cl_w45',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_num_event_0_cl_w45)',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'0',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_num_conversion_quote409_w60o30'],
#   u'Group': u'conversion_quote409',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': u'',
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'0',
#   u'ModelVarName': u'transvar_log_num_conversion_quote409_w60o30',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_num_conversion_quote409_w60o30)',
#   u'coeffLBound': u'-100000',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'1',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_count_conversion_all_w60o30'],
#   u'Group': u'conversion_all',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': 1.49093563373571,
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'0',
#   u'ModelVarName': u'stackmetric_count_conversion_all_w60o30',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'stackmetric_count_conversion_all_w60o30',
#   u'coeffLBound': u'-100000',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'0',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_num_event_otherevtseg_w45'],
#   u'Group': u'event_otherevtseg',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': u'',
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'1',
#   u'ModelVarName': u'transvar_log_num_event_otherevtseg_w45',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_num_event_otherevtseg_w45)',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'1',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_num_event_1_org_w45'],
#   u'Group': u'event_1_org',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': u'',
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'1',
#   u'ModelVarName': u'transvar_log_num_event_1_org_w45',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_num_event_1_org_w45)',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'1',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_numads30_event_0_org_w45'],
#   u'Group': u'event_0_org',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': u'',
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'1',
#   u'ModelVarName': u'transvar_log_numads30_event_0_org_w45',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_numads30_event_0_org_w45)',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'1',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_num_event_0_org_w45'],
#   u'Group': u'event_0_org',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': u'',
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'1',
#   u'ModelVarName': u'transvar_log_num_event_0_org_w45',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_num_event_0_org_w45)',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'1',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_num_webvisit_w60o30'],
#   u'Group': u'webvisit',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': 0.08477280561686501,
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'0',
#   u'ModelVarName': u'transvar_log_num_webvisit_w60o30',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_num_webvisit_w60o30)',
#   u'coeffLBound': u'-100000',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'0',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_num_event_0_org_w45',
#    u'stackmetric_num_event_1_org_w45'],
#   u'Group': u'event_organic_log',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': u'',
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'0',
#   u'ModelVarName': u'transvar_dummy_event_organic_log',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'LOG(stackmetric_num_event_0_org_w45 + stackmetric_num_event_1_org_w45)',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'1',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_numads30_event_otherevtseg_w45'],
#   u'Group': u'event_otherevtseg',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': u'',
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'1',
#   u'ModelVarName': u'transvar_log_numads30_event_otherevtseg_w45',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_numads30_event_otherevtseg_w45)',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'1',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_num_event_0_org_w45',
#    u'stackmetric_num_event_1_org_w45'],
#   u'Group': u'event_organic',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': 4.09477209212008,
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'0',
#   u'ModelVarName': u'transvar_dummy_event_organic',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'CASE WHEN stackmetric_num_event_0_org_w45 > 0 AND stackmetric_num_event_1_org_w45 > 0 THEN 1 ELSE 0 END',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'0',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_numads30_event_1_cl_w45'],
#   u'Group': u'event_1_cl',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': u'',
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'1',
#   u'ModelVarName': u'transvar_log_numads30_event_1_cl_w45',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_numads30_event_1_cl_w45)',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'1',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_numads30_event_1_im_w45'],
#   u'Group': u'event_1_im',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': u'',
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'1',
#   u'ModelVarName': u'transvar_log_numads30_event_1_im_w45',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_numads30_event_1_im_w45)',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'1',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_count_event_all_w45'],
#   u'Group': u'non_mktg_ind',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': 11.6100124983261,
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'0',
#   u'ModelVarName': u'transvar_non_mktg_ind',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'(1 - CASE WHEN  (stackmetric_count_event_all_w45)>0 THEN 1 ELSE 0 END)',
#   u'coeffLBound': u'-100000',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'0',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_num_event_1_im_w45'],
#   u'Group': u'event_1_im',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': 0.04273625579128901,
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'1',
#   u'ModelVarName': u'transvar_log_num_event_1_im_w45',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_num_event_1_im_w45)',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'0',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_numads30_event_1_org_w45'],
#   u'Group': u'event_1_org',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': u'',
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'1',
#   u'ModelVarName': u'transvar_log_numads30_event_1_org_w45',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_numads30_event_1_org_w45)',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'1',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_num_conversion_bindp045_w60o30'],
#   u'Group': u'conversion_bindp045',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': u'',
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'0',
#   u'ModelVarName': u'transvar_log_num_conversion_bindp045_w60o30',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_num_conversion_bindp045_w60o30)',
#   u'coeffLBound': u'-100000',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'1',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_num_conversion_compl594_w60o30'],
#   u'Group': u'conversion_compl594',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': u'',
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'0',
#   u'ModelVarName': u'transvar_log_num_conversion_compl594_w60o30',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_num_conversion_compl594_w60o30)',
#   u'coeffLBound': u'-100000',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'1',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_num_event_0_im_w45'],
#   u'Group': u'event_0_im',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': 0.184725181415689,
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'1',
#   u'ModelVarName': u'transvar_log_num_event_0_im_w45',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_num_event_0_im_w45)',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'0',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_num_conversion_otheractseg_w60o30'],
#   u'Group': u'conversion_otheractseg',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': u'',
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'0',
#   u'ModelVarName': u'transvar_log_num_conversion_otheractseg_w60o30',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_num_conversion_otheractseg_w60o30)',
#   u'coeffLBound': u'-100000',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'1',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'},
#  {u'AdditiveEventMetrics': [u'stackmetric_numads30_event_0_cl_w45'],
#   u'Group': u'event_0_cl',
#   u'IgnoreEventMetrics': [],
#   u'ModelVarCoeff': u'',
#   u'ModelVarIsDerived': u'1',
#   u'ModelVarMktgFlag': u'1',
#   u'ModelVarName': u'transvar_log_numads30_event_0_cl_w45',
#   u'NonAdditiveEventMetrics': [],
#   u'TransDefn': u'log(1+stackmetric_numads30_event_0_cl_w45)',
#   u'coeffLBound': u'0',
#   u'coeffUBound': u'100000',
#   u'flagCompulsoryGroup': u'0',
#   u'flagExclude': u'1',
#   u'percContLBounds': u'0',
#   u'percContUBounds': u'0.1',
#   u'priorMean': u'0.1',
#   u'rho': u'1E-7',
#   u'varPriority': u'0'}]

# %%
features = [f for f in all_features if (len(str(f['ModelVarCoeff'])) > 0 and
                                        int(f['flagExclude']) == 0
                                       )]
features
mkt_features = [f for f in features if int(f['ModelVarMktgFlag']) == 1]
non_mkt_features = [f for f in features if int(f['ModelVarMktgFlag']) == 0]
feature_names = [f['ModelVarName'] for f in features]
feature_names
# Out:
# [u'Intercept',
#  u'transvar_log_num_event_1_cl_w45',
#  u'transvar_log_num_event_0_cl_w45',
#  u'stackmetric_count_conversion_all_w60o30',
#  u'transvar_log_num_webvisit_w60o30',
#  u'transvar_dummy_event_organic',
#  u'transvar_non_mktg_ind',
#  u'transvar_log_num_event_1_im_w45',
#  u'transvar_log_num_event_0_im_w45']

# %% [markdown]
# ## Generation of transformed stack

# %%
skeleton = """
DROP VIEW IF EXISTS {db}.tmp_feature_stack;
DROP TABLE IF EXISTS {db}.tmp_feature_stack;
CREATE VIEW {db}.tmp_feature_stack AS
SELECT {features}
FROM {stack}
;"""

features_query = ', '.join(
    ['{} AS {}'.format(f['TransDefn'], f['ModelVarName'])
     if f['ModelVarName'] != 'Intercept' else
     '1 AS {}'.format(f['ModelVarName'])
     for f in features]
)

query = skeleton.format(
    db=db,
    stack=stack,
    features=features_query
)
print(query)
hive_query(query, raw=True, print_stderr=True)
# Out:
# DROP VIEW IF EXISTS joao.tmp_feature_stack;
# DROP TABLE IF EXISTS joao.tmp_feature_stack;
# CREATE VIEW joao.tmp_feature_stack AS
# SELECT 1 AS Intercept, log(1+stackmetric_num_event_1_cl_w45) AS transvar_log_num_event_1_cl_w45, log(1+stackmetric_num_event_0_cl_w45) AS transvar_log_num_event_0_cl_w45, stackmetric_count_conversion_all_w60o30 AS stackmetric_count_conversion_all_w60o30, log(1+stackmetric_num_webvisit_w60o30) AS transvar_log_num_webvisit_w60o30, CASE WHEN stackmetric_num_event_0_org_w45 > 0 AND stackmetric_num_event_1_org_w45 > 0 THEN 1 ELSE 0 END AS transvar_dummy_event_organic, (1 - CASE WHEN  (stackmetric_count_event_all_w45)>0 THEN 1 ELSE 0 END) AS transvar_non_mktg_ind, log(1+stackmetric_num_event_1_im_w45) AS transvar_log_num_event_1_im_w45, log(1+stackmetric_num_event_0_im_w45) AS transvar_log_num_event_0_im_w45
# FROM coeffstack_nwi_autotax3_mspnwi_nwi.coeffstack_base
# ;
#
# Logging initialized using configuration in file:/etc/hive-1.2.1/hive-log4j.properties
# Hive history file=/home/hive/log/joao/hive_job_log_1aa56123-7de1-40ec-982a-b1011b1596f0_218979882.txt
# OK
# Time taken: 1.146 seconds
# OK
# Time taken: 0.026 seconds
# OK
# Time taken: 0.694 seconds
# 'intercept\ttransvar_log_num_event_1_cl_w45\ttransvar_log_num_event_0_cl_w45\tstackmetric_count_conversion_all_w60o30\ttransvar_log_num_webvisit_w60o30\ttransvar_dummy_event_organic\ttransvar_non_mktg_ind\ttransvar_log_num_event_1_im_w45\ttransvar_log_num_event_0_im_w45\n'

# %% [markdown]
# ## Attribution

# %%
skeleton = """
DROP TABLE IF EXISTS {db}.tmp_attr_inter;
DROP VIEW IF EXISTS {db}.tmp_attr_inter;
CREATE VIEW {db}.tmp_attr_inter AS
SELECT
    {base_prob} AS base_prob,
    {total_prob} AS total_prob,
    ({base_prob})/({total_prob}) AS base_value,
    1 AS total_value,
    {raw_prob}
FROM {db}.tmp_feature_stack
;"""

all_terms = ' + '.join(
    ['{}*{}'.format(f['ModelVarCoeff'], f['ModelVarName']) for f in features])
mkt_terms = ' + '.join(
    ['{}*{}'.format(f['ModelVarCoeff'], f['ModelVarName']) for f in mkt_features])
nonmkt_terms = ' + '.join(
    ['{}*{}'.format(f['ModelVarCoeff'], f['ModelVarName']) for f in non_mkt_features])

base_prob = '1/(1+exp(-({})))'.format(nonmkt_terms)
total_prob = '1/(1+exp(-({})))'.format(all_terms)
raw_prob_list = []
for f in mkt_features:
    raw_prob_list.append(
        '1/(1+exp(-({}))) AS rawprob_{}'.format(
            ' + '.join(
                ['{0}*{1}'.format(fi['ModelVarCoeff'], fi['ModelVarName']) for fi in [f] + non_mkt_features]
            ),
            f['ModelVarName']
        )
    )
raw_prob = ', \n'.join(raw_prob_list)

query = skeleton.format(
    db=db,
    base_prob=base_prob,
    total_prob=total_prob,
    raw_prob=raw_prob
)
print(query)
hive_query(query, raw=True, print_stderr=True)
# Out:
# DROP TABLE IF EXISTS joao.tmp_attr_inter;
# DROP VIEW IF EXISTS joao.tmp_attr_inter;
# CREATE VIEW joao.tmp_attr_inter AS
# SELECT
#     1/(1+exp(-(-10.1195150319*Intercept + 1.49093563374*stackmetric_count_conversion_all_w60o30 + 0.0847728056169*transvar_log_num_webvisit_w60o30 + 4.09477209212*transvar_dummy_event_organic + 11.6100124983*transvar_non_mktg_ind))) AS base_prob,
#     1/(1+exp(-(-10.1195150319*Intercept + 0.149208929329*transvar_log_num_event_1_cl_w45 + 0.546911058329*transvar_log_num_event_0_cl_w45 + 1.49093563374*stackmetric_count_conversion_all_w60o30 + 0.0847728056169*transvar_log_num_webvisit_w60o30 + 4.09477209212*transvar_dummy_event_organic + 11.6100124983*transvar_non_mktg_ind + 0.0427362557913*transvar_log_num_event_1_im_w45 + 0.184725181416*transvar_log_num_event_0_im_w45))) AS total_prob,
#     (1/(1+exp(-(-10.1195150319*Intercept + 1.49093563374*stackmetric_count_conversion_all_w60o30 + 0.0847728056169*transvar_log_num_webvisit_w60o30 + 4.09477209212*transvar_dummy_event_organic + 11.6100124983*transvar_non_mktg_ind))))/(1/(1+exp(-(-10.1195150319*Intercept + 0.149208929329*transvar_log_num_event_1_cl_w45 + 0.546911058329*transvar_log_num_event_0_cl_w45 + 1.49093563374*stackmetric_count_conversion_all_w60o30 + 0.0847728056169*transvar_log_num_webvisit_w60o30 + 4.09477209212*transvar_dummy_event_organic + 11.6100124983*transvar_non_mktg_ind + 0.0427362557913*transvar_log_num_event_1_im_w45 + 0.184725181416*transvar_log_num_event_0_im_w45)))) AS base_value,
#     1 AS total_value,
#     1/(1+exp(-(0.149208929329*transvar_log_num_event_1_cl_w45 + -10.1195150319*Intercept + 1.49093563374*stackmetric_count_conversion_all_w60o30 + 0.0847728056169*transvar_log_num_webvisit_w60o30 + 4.09477209212*transvar_dummy_event_organic + 11.6100124983*transvar_non_mktg_ind))) AS rawprob_transvar_log_num_event_1_cl_w45,
# 1/(1+exp(-(0.546911058329*transvar_log_num_event_0_cl_w45 + -10.1195150319*Intercept + 1.49093563374*stackmetric_count_conversion_all_w60o30 + 0.0847728056169*transvar_log_num_webvisit_w60o30 + 4.09477209212*transvar_dummy_event_organic + 11.6100124983*transvar_non_mktg_ind))) AS rawprob_transvar_log_num_event_0_cl_w45,
# 1/(1+exp(-(0.0427362557913*transvar_log_num_event_1_im_w45 + -10.1195150319*Intercept + 1.49093563374*stackmetric_count_conversion_all_w60o30 + 0.0847728056169*transvar_log_num_webvisit_w60o30 + 4.09477209212*transvar_dummy_event_organic + 11.6100124983*transvar_non_mktg_ind))) AS rawprob_transvar_log_num_event_1_im_w45,
# 1/(1+exp(-(0.184725181416*transvar_log_num_event_0_im_w45 + -10.1195150319*Intercept + 1.49093563374*stackmetric_count_conversion_all_w60o30 + 0.0847728056169*transvar_log_num_webvisit_w60o30 + 4.09477209212*transvar_dummy_event_organic + 11.6100124983*transvar_non_mktg_ind))) AS rawprob_transvar_log_num_event_0_im_w45
# FROM joao.tmp_feature_stack
# ;
#
# Logging initialized using configuration in file:/etc/hive-1.2.1/hive-log4j.properties
# Hive history file=/home/hive/log/joao/hive_job_log_003abf63-e136-4e40-81aa-ee8fcc1bd982_808509993.txt
# OK
# Time taken: 1.168 seconds
# OK
# Time taken: 0.025 seconds
# OK
# Time taken: 1.086 seconds
# 'base_prob\ttotal_prob\tbase_value\ttotal_value\trawprob_transvar_log_num_event_1_cl_w45\trawprob_transvar_log_num_event_0_cl_w45\trawprob_transvar_log_num_event_1_im_w45\trawprob_transvar_log_num_event_0_im_w45\n'

# %%
skeleton = """
DROP TABLE IF EXISTS {db}.tmp_attr;
DROP VIEW IF EXISTS {db}.tmp_attr;
CREATE TABLE {db}.tmp_attr AS
SELECT
    base_prob,
    total_prob,
    base_value,
    total_value,
    {mkt_features},
    {raw_prob_sum} AS raw_prob_sum,
    {rel_attr_pct},
    {mar_attr}
FROM {db}.tmp_attr_inter
;"""

rel_attr_pct = ',\n'.join(
    ['{0}/({1}) AS relattr_{0}'.format('rawprob_{}'.format(f['ModelVarName']),
                                       ' + '.join(['rawprob_{}'.format(f['ModelVarName']) for f in mkt_features])) for f in mkt_features]
)

mar_attr = ',\n'.join(
    ['(total_value - base_value) * {0}/({1}) AS marattr_{0}'.format('rawprob_{}'.format(f['ModelVarName']),
                                                                    ' + '.join(['rawprob_{}'.format(f['ModelVarName']) for f in mkt_features])) for f in mkt_features]
)

query = skeleton.format(
    db=db,
    mkt_features=', '.join(['rawprob_{}'.format(f['ModelVarName']) for f in mkt_features]),
    raw_prob_sum=' + '.join(['rawprob_{}'.format(f['ModelVarName']) for f in mkt_features]),
    rel_attr_pct=rel_attr_pct,
    mar_attr=mar_attr
)
print(query)
hive_query(query, raw=True, print_stderr=True)
# Out:
# DROP TABLE IF EXISTS joao.tmp_attr;
# DROP VIEW IF EXISTS joao.tmp_attr;
# CREATE TABLE joao.tmp_attr AS
# SELECT
#     base_prob,
#     total_prob,
#     base_value,
#     total_value,
#     rawprob_transvar_log_num_event_1_cl_w45, rawprob_transvar_log_num_event_0_cl_w45, rawprob_transvar_log_num_event_1_im_w45, rawprob_transvar_log_num_event_0_im_w45,
#     rawprob_transvar_log_num_event_1_cl_w45 + rawprob_transvar_log_num_event_0_cl_w45 + rawprob_transvar_log_num_event_1_im_w45 + rawprob_transvar_log_num_event_0_im_w45 AS raw_prob_sum,
#     rawprob_transvar_log_num_event_1_cl_w45/(rawprob_transvar_log_num_event_1_cl_w45 + rawprob_transvar_log_num_event_0_cl_w45 + rawprob_transvar_log_num_event_1_im_w45 + rawprob_transvar_log_num_event_0_im_w45) AS relattr_rawprob_transvar_log_num_event_1_cl_w45,
# rawprob_transvar_log_num_event_0_cl_w45/(rawprob_transvar_log_num_event_1_cl_w45 + rawprob_transvar_log_num_event_0_cl_w45 + rawprob_transvar_log_num_event_1_im_w45 + rawprob_transvar_log_num_event_0_im_w45) AS relattr_rawprob_transvar_log_num_event_0_cl_w45,
# rawprob_transvar_log_num_event_1_im_w45/(rawprob_transvar_log_num_event_1_cl_w45 + rawprob_transvar_log_num_event_0_cl_w45 + rawprob_transvar_log_num_event_1_im_w45 + rawprob_transvar_log_num_event_0_im_w45) AS relattr_rawprob_transvar_log_num_event_1_im_w45,
# rawprob_transvar_log_num_event_0_im_w45/(rawprob_transvar_log_num_event_1_cl_w45 + rawprob_transvar_log_num_event_0_cl_w45 + rawprob_transvar_log_num_event_1_im_w45 + rawprob_transvar_log_num_event_0_im_w45) AS relattr_rawprob_transvar_log_num_event_0_im_w45,
#     (total_value - base_value) * rawprob_transvar_log_num_event_1_cl_w45/(rawprob_transvar_log_num_event_1_cl_w45 + rawprob_transvar_log_num_event_0_cl_w45 + rawprob_transvar_log_num_event_1_im_w45 + rawprob_transvar_log_num_event_0_im_w45) AS marattr_rawprob_transvar_log_num_event_1_cl_w45,
# (total_value - base_value) * rawprob_transvar_log_num_event_0_cl_w45/(rawprob_transvar_log_num_event_1_cl_w45 + rawprob_transvar_log_num_event_0_cl_w45 + rawprob_transvar_log_num_event_1_im_w45 + rawprob_transvar_log_num_event_0_im_w45) AS marattr_rawprob_transvar_log_num_event_0_cl_w45,
# (total_value - base_value) * rawprob_transvar_log_num_event_1_im_w45/(rawprob_transvar_log_num_event_1_cl_w45 + rawprob_transvar_log_num_event_0_cl_w45 + rawprob_transvar_log_num_event_1_im_w45 + rawprob_transvar_log_num_event_0_im_w45) AS marattr_rawprob_transvar_log_num_event_1_im_w45,
# (total_value - base_value) * rawprob_transvar_log_num_event_0_im_w45/(rawprob_transvar_log_num_event_1_cl_w45 + rawprob_transvar_log_num_event_0_cl_w45 + rawprob_transvar_log_num_event_1_im_w45 + rawprob_transvar_log_num_event_0_im_w45) AS marattr_rawprob_transvar_log_num_event_0_im_w45
# FROM joao.tmp_attr_inter
# ;
#
# Logging initialized using configuration in file:/etc/hive-1.2.1/hive-log4j.properties
# Hive history file=/home/hive/log/joao/hive_job_log_66961ced-ff21-4ac1-97fb-8c0d719d7deb_293786943.txt
# OK
# Time taken: 1.163 seconds
# OK
# Time taken: 0.026 seconds
# Query ID = joao_20170120212439_c56f0518-3857-42f9-8cbf-ad59aaf576d0
# Total jobs = 1
# Launching Job 1 out of 1
#
#
# Status: Running (Executing on YARN cluster with App id application_1478567810965_43149)
#
# Map 1: -/-
# Map 1: 0/18
# Map 1: 0/18
# Map 1: 0(+4)/18
# Map 1: 2(+2)/18
# Map 1: 2(+16)/18
# Map 1: 2(+16)/18
# Map 1: 5(+12)/18
# Map 1: 8(+10)/18
# Map 1: 8(+10)/18
# Map 1: 8(+10)/18
# Map 1: 8(+10)/18
# Map 1: 8(+10)/18
# Map 1: 8(+10)/18
# Map 1: 8(+10)/18
# Map 1: 8(+10)/18
# Map 1: 8(+10)/18
# Map 1: 8(+10)/18
# Map 1: 8(+10)/18
# Map 1: 8(+10)/18
# Map 1: 8(+10)/18
# Map 1: 8(+10)/18
# Map 1: 8(+10)/18
# Map 1: 9(+9)/18
# Map 1: 10(+8)/18
# Map 1: 10(+8)/18
# Map 1: 10(+8)/18
# Map 1: 11(+7)/18
# Map 1: 12(+6)/18
# Map 1: 13(+5)/18
# Map 1: 14(+4)/18
# Map 1: 16(+2)/18
# Map 1: 17(+1)/18
# Map 1: 18/18
# Moving data to: hdfs://nn-ms22.s3s.altiscale.com:8020/hive/joao.db/tmp_attr
# OK
# Time taken: 88.576 seconds
# 'base_prob\ttotal_prob\tbase_value\ttotal_value\trawprob_transvar_log_num_event_1_cl_w45\trawprob_transvar_log_num_event_0_cl_w45\trawprob_transvar_log_num_event_1_im_w45\trawprob_transvar_log_num_event_0_im_w45\traw_prob_sum\trelattr_rawprob_transvar_log_num_event_1_cl_w45\trelattr_rawprob_transvar_log_num_event_0_cl_w45\trelattr_rawprob_transvar_log_num_event_1_im_w45\trelattr_rawprob_transvar_log_num_event_0_im_w45\tmarattr_rawprob_transvar_log_num_event_1_cl_w45\tmarattr_rawprob_transvar_log_num_event_0_cl_w45\tmarattr_rawprob_transvar_log_num_event_1_im_w45\tmarattr_rawprob_transvar_log_num_event_0_im_w45\n'

# %% [markdown]
# ## Comparison with DN
