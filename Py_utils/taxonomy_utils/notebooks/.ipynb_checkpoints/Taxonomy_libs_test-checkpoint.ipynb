# %%
import sys, os, inspect
sys.path.append("/home/vbhargava/feature_test0/msaction_backend/common/BU3.0_core/util/Py_utils/taxonomy_utils")

# %%
import time, logging
numeric_level = getattr(logging, 'DEBUG', None)
stdout_handler = logging.StreamHandler(sys.stdout)
logging.basicConfig(level=numeric_level,
                        format='%(asctime)s %(levelname)s %(name)s: %(message)s',
                        handlers=[stdout_handler])

# %% [markdown]
# ## Platform Config Lib Test
# #### parsing platform config xml

# %%
config = '/home/vbhargava/feature_test0/msaction_backend/customers/raj_ford_test/common/config/inputs/platform_config.xml'

# %%
from libs.configs import Config

# %%
Config.get_qubole_config(config)
# Out:
# {'s3_location': 's3://qubole-ford/warehouse/',
#  'token': '222a6d7cd10b40c08e8a0f969f6f2f65934aad594b5b40a19f1d65aa3a4597f1',
#  'url': 'https://api.qubole.com/api',
#  'cluster': 'Ford-V4-Dnow',
#  'access_key': 'AKIAV7ASTURNMFCYWFNJ',
#  'secret_key': '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'}

# %% [markdown]
# # NIO test
# ### NIO executor

# %%
from libs.nio_executor import NIO

# %%
tasks_args_list =  [['abc', 'l'], ['cde', 'n']]
NIO.run_io(task=NIO.sample_task, task_n_args_list=tasks_args_list)
# Out:
# 2020-10-18 11:54:53,774 DEBUG asyncio: Using selector: EpollSelector
# 2020-10-18 11:54:53,776 INFO run_blocking_tasks: starting
# 2020-10-18 11:54:53,776 INFO run_blocking_tasks: creating executor tasks
# 2020-10-18 11:54:53,778 INFO (task-0): passed args :['abc', 'l']
# 2020-10-18 11:54:53,778 INFO (task-1): passed args :['cde', 'n']
# 2020-10-18 11:54:53,778 INFO run_blocking_tasks: waiting for executor tasks
# 2020-10-18 11:54:53,779 INFO (task-0): running
# 2020-10-18 11:54:53,779 INFO (task-1): running
# 2020-10-18 11:54:53,782 INFO (task-0): ==><bound method NIO.sample_task of <class 'libs.nio_executor.NIO'>>
# 2020-10-18 11:54:53,782 INFO (task-1): ==><bound method NIO.sample_task of <class 'libs.nio_executor.NIO'>>
# 2020-10-18 11:54:53,783 ERROR root: decoding str is not supported
# Traceback (most recent call last):
#   File "/home/vbhargava/feature_test0/msaction_backend/common/BU3.0_core/util/Py_utils/taxonomy_utils/libs/nio_executor.py", line 34, in task_wrapper
# ...

# %%
tasks_args_list =  [['abc', 'l'], ['cde', 'n']]
NIO.decorated_run_io(task=NIO.sample_task, task_n_args_list=tasks_args_list)
# Out:
# 2020-10-18 11:54:53,794:93671 MainThread asyncio: Using selector: EpollSelector
#
# 2020-10-18 11:54:53,795:93671 MainThread run_blocking_tasks: starting
#
# 2020-10-18 11:54:53,796:93671 MainThread run_blocking_tasks: creating executor tasks
#
# 2020-10-18 11:54:53,796:93671 ThreadPoolExecutor-1_0 (task-0): passed args :['abc', 'l']
#
# 2020-10-18 11:54:53,797:93671 ThreadPoolExecutor-1_1 (task-1): passed args :['cde', 'n']
#
# 2020-10-18 11:54:53,797:93671 MainThread run_blocking_tasks: waiting for executor tasks
#
# 2020-10-18 11:54:53,797:93671 ThreadPoolExecutor-1_0 (task-0): running
#
# 2020-10-18 11:54:53,798:93671 ThreadPoolExecutor-1_1 (task-1): running
#
# 2020-10-18 11:54:53,800:93671 ThreadPoolExecutor-1_0 (task-0): ==><bound method NIO.sample_task of <class 'libs.nio_executor.NIO'>>
#
# 2020-10-18 11:54:53,801:93671 ThreadPoolExecutor-1_1 (task-1): ==><bound method NIO.sample_task of <class 'libs.nio_executor.NIO'>>
#
# ...

# %%
tasks_dict = {'task_1':['k', 'l'], 'task_2':['m', 'n']}
NIO.execute_io(func=NIO.sample_task, max_workers=10, is_kernal_thread=True, **tasks_dict)
# Out:
# 2020-10-18 11:54:53,817 DEBUG asyncio: Using selector: EpollSelector
# 2020-10-18 11:54:53,818 INFO run_blocking_tasks: starting
# 2020-10-18 11:54:53,819 INFO run_blocking_tasks: creating executor tasks
# 2020-10-18 11:54:53,845 INFO run_blocking_tasks: waiting for executor tasks
# 2020-10-18 11:54:53,846 INFO (task_1): passed args :['k', 'l']
# 2020-10-18 11:54:53,847 INFO (task_2): passed args :['m', 'n']
# 2020-10-18 11:54:53,849 INFO (task_1): running
# 2020-10-18 11:54:53,849 INFO (task_2): running
# 2020-10-18 11:54:53,850 INFO (task_1): ==><bound method NIO.sample_task of <class 'libs.nio_executor.NIO'>>
# 2020-10-18 11:54:53,850 INFO (task_2): ==><bound method NIO.sample_task of <class 'libs.nio_executor.NIO'>>
# 2020-10-18 11:54:53,851 ERROR root: decoding str is not supported
# Traceback (most recent call last):
#   File "/home/vbhargava/feature_test0/msaction_backend/common/BU3.0_core/util/Py_utils/taxonomy_utils/libs/nio_executor.py", line 34, in task_wrapper
# ...

# %%
tasks_n_args_list =  [['abc', 'l'], ['cde', 'n']]
NIO.decorated_run_io(task=NIO.sample_task, task_n_args_list=tasks_n_args_list, is_kernal_thread=True,)
# Out:
# 2020-10-18 11:54:53,863   process-id:93671    asyncio: Using selector: EpollSelector
#
# 2020-10-18 11:54:53,865   process-id:93671 run_blocking_tasks: starting
#
# 2020-10-18 11:54:53,866   process-id:93671 run_blocking_tasks: creating executor tasks
#
# 2020-10-18 11:54:53,893   process-id:93671 run_blocking_tasks: waiting for executor tasks
#
# 2020-10-18 11:54:53,895   process-id:93729   (task-0): passed args :['abc', 'l']
#
# 2020-10-18 11:54:53,895   process-id:93730   (task-1): passed args :['cde', 'n']
#
# 2020-10-18 11:54:53,898   process-id:93729   (task-0): running
#
# 2020-10-18 11:54:53,898   process-id:93730   (task-1): running
#
# 2020-10-18 11:54:53,899   process-id:93729   (task-0): ==><bound method NIO.sample_task of <class 'libs.nio_executor.NIO'>>
#
# 2020-10-18 11:54:53,899   process-id:93730   (task-1): ==><bound method NIO.sample_task of <class 'libs.nio_executor.NIO'>>
#
# 2020-10-18 11:54:53,900   process-id:93729       root: decoding str is not supported
# ...

# %%
tasks_n_args_list =  [[NIO.sample_task, 'abc', 'l'], [NIO.sample_task2, 'cde', 'n']]
NIO.decorated_execute_tasklist(task_n_args_list=tasks_n_args_list,is_kernal_thread=True,)
# Out:
# 2020-10-18 11:54:53,913   process-id:93671    asyncio: Using selector: EpollSelector
#
# 2020-10-18 11:54:53,916   process-id:93671 run_blocking_tasks: starting
#
# 2020-10-18 11:54:53,916   process-id:93671 run_blocking_tasks: creating executor tasks
#
# 2020-10-18 11:54:53,944   process-id:93671 run_blocking_tasks: waiting for executor tasks
#
# 2020-10-18 11:54:53,945   process-id:93761   (task-0): passed args :['abc', 'l']
#
# 2020-10-18 11:54:53,947   process-id:93761   (task-0): running
#
# 2020-10-18 11:54:53,949   process-id:93761   (task-0): ==><bound method NIO.sample_task of <class 'libs.nio_executor.NIO'>>
#
# 2020-10-18 11:54:53,948   process-id:93762   (task-1): passed args :['cde', 'n']
#
# 2020-10-18 11:54:53,949   process-id:93761       root: decoding str is not supported
# Traceback (most recent call last):
#   File "/home/vbhargava/feature_test0/msaction_backend/common/BU3.0_core/util/Py_utils/taxonomy_utils/libs/nio_executor.py", line 34, in task_wrapper
# ...

# %% [markdown]
# ### Custom tasks

# %%
def custom_task(arg1, arg2, arg3, arg4=-1):
    log = logging.getLogger('(custom_task)')
    log.info("under custom task")

    return str(arg1)+str(arg2)+str(arg3)+str(arg4)

# def custom_task(*arg):
#     log = logging.getLogger('(custom_task)')
#     log.info("under custom task")

#     return arg

tasks_n_args_list =  [
                        [NIO.sample_task, 'abc', 'l'], 
                        [NIO.sample_task2, 'cde', 'n'],
                        [custom_task, '0', '0', '1'],
                        [custom_task, '0', '1', '0'],
                        [custom_task, '0', '1', '1'],
                        [custom_task, '1', '0', '0'],
                        [custom_task, '1', '0', '1'],
                        [custom_task, '1', '1', '0'],
                        [custom_task, '1', '1', '1'],
                        [custom_task, '1', '0', '0', '0'],
                        [custom_task, '1', '0', '0', '1'],
                        [custom_task, '1', '0', '1', '0'],
                        [custom_task, '1', '0', '1', '1'],
                        [custom_task, '1', '1', '0', '0'],
                        [custom_task, '1', '1', '0', '1'],
                        [custom_task, '1', '1', '1', '0'],
                        [custom_task, '1', '1', '1', '1'],
                        
                     ]
NIO.decorated_execute_tasklist(task_n_args_list=tasks_n_args_list)
# Out:
# 2020-10-18 11:54:53,968:93671 MainThread asyncio: Using selector: EpollSelector
#
# 2020-10-18 11:54:53,969:93671 MainThread run_blocking_tasks: starting
#
# 2020-10-18 11:54:53,970:93671 MainThread run_blocking_tasks: creating executor tasks
#
# 2020-10-18 11:54:53,971:93671 ThreadPoolExecutor-2_0 (task-0): passed args :['abc', 'l']
#
# 2020-10-18 11:54:53,971:93671 ThreadPoolExecutor-2_1 (task-1): passed args :['cde', 'n']
#
# 2020-10-18 11:54:53,972:93671 ThreadPoolExecutor-2_2 (task-2): passed args :['0', '0', '1']
#
# 2020-10-18 11:54:53,972:93671 ThreadPoolExecutor-2_3 (task-3): passed args :['0', '1', '0']
#
# 2020-10-18 11:54:53,972:93671 ThreadPoolExecutor-2_0 (task-0): running
#
# 2020-10-18 11:54:53,973:93671 ThreadPoolExecutor-2_4 (task-4): passed args :['0', '1', '1']
#
# 2020-10-18 11:54:53,974:93671 ThreadPoolExecutor-2_5 (task-5): passed args :['1', '0', '0']
#
# 2020-10-18 11:54:53,975:93671 ThreadPoolExecutor-2_6 (task-6): passed args :['1', '0', '1']
#
# ...

# %%
tasks_n_args_list =  [
                        (NIO.sample_task, 'abc', 'l'), 
                        (NIO.sample_task2, 'cde', 'n'),
                        (custom_task, '0', '0', '1'),
                        (custom_task, '0', '1', '0'),
                        (custom_task, '0', '1', '1'),
                        (custom_task, '1', '0', '0'),
                        (custom_task, '1', '0', '1'),
                        (custom_task, '1', '1', '0'),
                        (custom_task, '1', '1', '1'),
                        (custom_task, '1', '0', '0', '0'),
                        (custom_task, '1', '0', '0', '1'),
                        (custom_task, '1', '0', '1', '0'),
                        (custom_task, '1', '0', '1', '1'),
                        (custom_task, '1', '1', '0', '0'),
                        (custom_task, '1', '1', '0', '1'),
                        (custom_task, '1', '1', '1', '0'),
                        (custom_task, '1', '1', '1', '1'),
                        
                     ]
NIO.decorated_execute_tasklist(task_n_args_list=tasks_n_args_list,)
# Out:
# 2020-10-18 11:54:54,049:93671 MainThread asyncio: Using selector: EpollSelector
#
# 2020-10-18 11:54:54,051:93671 MainThread run_blocking_tasks: starting
#
# 2020-10-18 11:54:54,052:93671 MainThread run_blocking_tasks: creating executor tasks
#
# 2020-10-18 11:54:54,052:93671 ThreadPoolExecutor-3_0 (task-0): passed args :('abc', 'l')
#
# 2020-10-18 11:54:54,053:93671 ThreadPoolExecutor-3_1 (task-1): passed args :('cde', 'n')
#
# 2020-10-18 11:54:54,053:93671 ThreadPoolExecutor-3_0 (task-0): running
#
# 2020-10-18 11:54:54,054:93671 ThreadPoolExecutor-3_2 (task-2): passed args :('0', '0', '1')
#
# 2020-10-18 11:54:54,054:93671 ThreadPoolExecutor-3_3 (task-3): passed args :('0', '1', '0')
#
# 2020-10-18 11:54:54,055:93671 ThreadPoolExecutor-3_4 (task-4): passed args :('0', '1', '1')
#
# 2020-10-18 11:54:54,056:93671 ThreadPoolExecutor-3_5 (task-5): passed args :('1', '0', '0')
#
# 2020-10-18 11:54:54,056:93671 ThreadPoolExecutor-3_6 (task-6): passed args :('1', '0', '1')
#
# ...

# %%
NIO.decorated_execute_tasklist(task_n_args_list=tasks_n_args_list,is_kernal_thread=True,)
# Out:
# 2020-10-18 11:54:54,126   process-id:93671    asyncio: Using selector: EpollSelector
#
# 2020-10-18 11:54:54,127   process-id:93671 run_blocking_tasks: starting
#
# 2020-10-18 11:54:54,128   process-id:93671 run_blocking_tasks: creating executor tasks
#
# 2020-10-18 11:54:54,160   process-id:93671 run_blocking_tasks: waiting for executor tasks
#
# 2020-10-18 11:54:54,163   process-id:93813   (task-0): passed args :('abc', 'l')
#
# 2020-10-18 11:54:54,163   process-id:93814   (task-1): passed args :('cde', 'n')
#
# 2020-10-18 11:54:54,164   process-id:93820   (task-7): passed args :('1', '1', '0')
#
# 2020-10-18 11:54:54,164   process-id:93819   (task-6): passed args :('1', '0', '1')
#
# 2020-10-18 11:54:54,163   process-id:93816   (task-3): passed args :('0', '1', '0')
#
# 2020-10-18 11:54:54,163   process-id:93815   (task-2): passed args :('0', '0', '1')
#
# 2020-10-18 11:54:54,164   process-id:93818   (task-5): passed args :('1', '0', '0')
#
# ...

# %%
NIO.decorated_execute_tasklist(tasks_n_args_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-e2e13c152e00> in <module>
# ----> 1 NIO.decorated_execute_tasklist(tasks_n_args_list)
#
# ~/feature_test0/msaction_backend/common/BU3.0_core/util/Py_utils/taxonomy_utils/libs/nio_executor.py in decorated_execute_tasklist(cls, max_workers, is_kernal_thread, task_n_args_list)
#     219         else:
#     220             log_decorate(cls.execute_tasklist, max_workers=max_workers,
# --> 221                      is_kernal_thread=is_kernal_thread,task_n_args_list=task_n_args_list)
#     222
#
# ~/feature_test0/msaction_backend/common/BU3.0_core/util/Py_utils/taxonomy_utils/libs/log_decorator.py in log_decorate(func, formattor, **kwargs)
#       6     exiting_formattor = ROOT_LOGGER.handlers[0].formatter
#       7     ROOT_LOGGER.handlers[0].setFormatter(logging.Formatter(formattor))
# ----> 8     func(**kwargs)
# ...

# %%
tasks_n_args_list1=[
                    [NIO.sample_task, 'abc', 'l'], 
                     #[NIO.sample_task2, 'cde', 'n'], 
                    ]

def test12(tasks_n_args_list):
    NIO.decorated_execute_tasklist(task_n_args_list=tasks_n_args_list)
    return 'completed'
    
    
tasks_n_args_list=    [ 
                        [test12, tasks_n_args_list1]
                       ]

# tasks_n_args_list =  [
#                         [NIO.sample_task, 'abc', 'l'], 
#                         [NIO.sample_task2, 'cde', 'n'],
#                         [custom_task, '0', '0', '1'],
#                         [custom_task, '0', '1', '0'],
#                         [custom_task, '0', '1', '1'],
#                         [custom_task, '1', '0', '0'],
#                         [custom_task, '1', '0', '1'],
#                         [custom_task, '1', '1', '0'],
#                         [custom_task, '1', '1', '1'],
#                         [custom_task, '1', '0', '0', '0'],
#                         [custom_task, '1', '0', '0', '1'],
#                         [custom_task, '1', '0', '1', '0'],
#                         [custom_task, '1', '0', '1', '1'],
#                         [custom_task, '1', '1', '0', '0'],
#                         [custom_task, '1', '1', '0', '1'],
#                         [custom_task, '1', '1', '1', '0'],
#                         [custom_task, '1', '1', '1', '1'],
                        
#                      ]
NIO.decorated_execute_tasklist(task_n_args_list=tasks_n_args_list, is_kernal_thread=True,)
# Out:
# 2020-10-18 11:55:45,990   process-id:93671    asyncio: Using selector: EpollSelector
#
# 2020-10-18 11:55:45,991   process-id:93671 run_blocking_tasks: starting
#
# 2020-10-18 11:55:45,991   process-id:93671 run_blocking_tasks: creating executor tasks
#
# 2020-10-18 11:55:46,019   process-id:93671 run_blocking_tasks: waiting for executor tasks
#
# 2020-10-18 11:55:46,022   process-id:96886   (task-0): passed args :[[[<bound method NIO.sample_task of <class 'libs.nio_executor.NIO'>>, 'abc', 'l']]]
#
# 2020-10-18 11:55:46,025   process-id:96886   (task-0): running
#
# 2020-10-18 11:55:46,026   process-id:96886   (task-0): ==><bound method NIO.decorated_execute_tasklist of <class 'libs.nio_executor.NIO'>>
#
# 2020-10-18 11:55:46,027   process-id:96886   (task-0): ==>[[<bound method NIO.sample_task of <class 'libs.nio_executor.NIO'>>, 'abc', 'l']]
#
# 2020-10-18 11:55:46,028:96886 MainThread root: '<=' not supported between instances of 'list' and 'int'
# ...

# %%
custom_task.__str__
# Out:
# <method-wrapper '__str__' of function object at 0x7fb83c6cd9d8>
