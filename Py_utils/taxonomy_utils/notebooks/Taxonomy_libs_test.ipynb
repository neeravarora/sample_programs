# %%
import sys, os, inspect
import time
sys.path.append("/home/vbhargava/feature_test0/msaction_backend/common/BU3.0_core/util/Py_utils/taxonomy_utils")

# %%
import time, logging
from random import random,Random
numeric_level = getattr(logging, 'DEBUG', None)
stdout_handler = logging.StreamHandler(sys.stdout)
logging.basicConfig(level=numeric_level,
                        format='%(asctime)s %(levelname)s %(name)s: %(message)s',
                        handlers=[stdout_handler])

# %% [markdown]
# ## Platform Config Lib Test
# #### parsing platform config xml

# %%
config = '/home/vbhargava/feature_test0/msaction_backend/customers/raj_ford_test/common/config/inputs/platform_config.xml'

# %%
from libs.configs import Config

# %%
Config.get_qubole_config(config)
# Out:
# {'s3_location': 's3://qubole-ford/warehouse/',
#  'token': '222a6d7cd10b40c08e8a0f969f6f2f65934aad594b5b40a19f1d65aa3a4597f1',
#  'url': 'https://api.qubole.com/api',
#  'cluster': 'Ford-V4-Dnow',
#  'access_key': 'AKIAV7ASTURNMFCYWFNJ',
#  'secret_key': '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',
#  'region': 'us-east-1'}

# %% [markdown]
# # NIO test
# ### NIO executor

# %%
from libs.nio_executor import NIO

# %%
tasks_args_list =  [['abc', 'l'], ['cde', 'n']]
collected = NIO.run_io(task=NIO.sample_task, task_n_args_list=tasks_args_list)
collected
# Out:
# 2020-10-22 15:05:14,482 DEBUG asyncio: Using selector: EpollSelector
# 2020-10-22 15:05:14,483 INFO run_blocking_tasks: starting
# 2020-10-22 15:05:14,483 INFO run_blocking_tasks: creating executor tasks
# 2020-10-22 15:05:14,484 INFO (task-0): passed args :['abc', 'l']
# 2020-10-22 15:05:14,485 INFO (task-1): passed args :['cde', 'n']
# 2020-10-22 15:05:14,485 INFO run_blocking_tasks: waiting for executor tasks
# 2020-10-22 15:05:14,485 INFO (task-0): running
# 2020-10-22 15:05:14,486 INFO (task-1): running
# 2020-10-22 15:05:14,488 INFO (sample_task): under task
# 2020-10-22 15:05:14,489 INFO (sample_task): under task
# 2020-10-22 15:05:14,489 INFO (task-0): done
# 2020-10-22 15:05:14,490 INFO (task-1): done
# ...

# %%
tasks_args_list =  [['abc', 'l'], ['cde', 'n']]
collected = NIO.decorated_run_io(task=NIO.sample_task, task_n_args_list=tasks_args_list)
collected
# Out:
# 2020-10-22 15:05:14,500:120962 MainThread asyncio: Using selector: EpollSelector
#
# 2020-10-22 15:05:14,501:120962 MainThread run_blocking_tasks: starting
#
# 2020-10-22 15:05:14,501:120962 MainThread run_blocking_tasks: creating executor tasks
#
# 2020-10-22 15:05:14,502:120962 ThreadPoolExecutor-1_0 (task-0): passed args :['abc', 'l']
#
# 2020-10-22 15:05:14,502:120962 ThreadPoolExecutor-1_1 (task-1): passed args :['cde', 'n']
#
# 2020-10-22 15:05:14,503:120962 MainThread run_blocking_tasks: waiting for executor tasks
#
# 2020-10-22 15:05:14,503:120962 ThreadPoolExecutor-1_0 (task-0): running
#
# 2020-10-22 15:05:14,504:120962 ThreadPoolExecutor-1_1 (task-1): running
#
# 2020-10-22 15:05:14,506:120962 ThreadPoolExecutor-1_0 (sample_task): under task
#
# 2020-10-22 15:05:14,506:120962 ThreadPoolExecutor-1_1 (sample_task): under task
#
# 2020-10-22 15:05:14,507:120962 ThreadPoolExecutor-1_0 (task-0): done
#
# 2020-10-22 15:05:14,508:120962 ThreadPoolExecutor-1_1 (task-1): done
#
# ...

# %%
tasks_dict = {'task_1':['k', 'l'], 'task_2':['m', 'n']}
#result = {'taskId':'', 'task':'', 'args': , :"result", error}

collected = NIO.execute_io(func=NIO.sample_task, max_workers=10, is_kernal_thread=True, **tasks_dict)
collected
# Out:
# 2020-10-22 15:05:14,523 DEBUG asyncio: Using selector: EpollSelector
# 2020-10-22 15:05:14,524 INFO run_blocking_tasks: starting
# 2020-10-22 15:05:14,524 INFO run_blocking_tasks: creating executor tasks
# 2020-10-22 15:05:14,552 INFO run_blocking_tasks: waiting for executor tasks
# 2020-10-22 15:05:14,554 INFO (task_2): passed args :['m', 'n']
# 2020-10-22 15:05:14,553 INFO (task_1): passed args :['k', 'l']
# 2020-10-22 15:05:14,556 INFO (task_1): running
# 2020-10-22 15:05:14,556 INFO (task_2): running
# 2020-10-22 15:05:14,558 INFO (sample_task): under task
# 2020-10-22 15:05:14,558 INFO (sample_task): under task
# 2020-10-22 15:05:14,559 INFO (task_2): done
# 2020-10-22 15:05:14,559 INFO (task_1): done
# ...

# %%
tasks_n_args_list =  [['abc', 'l'], ['cde', 'n']]
collected = NIO.decorated_run_io(task=NIO.sample_task, task_n_args_list=tasks_n_args_list, is_kernal_thread=True,)
collected
# Out:
# 2020-10-22 15:05:14,574   process-id:120962    asyncio: Using selector: EpollSelector
#
# 2020-10-22 15:05:14,576   process-id:120962 run_blocking_tasks: starting
#
# 2020-10-22 15:05:14,577   process-id:120962 run_blocking_tasks: creating executor tasks
#
# 2020-10-22 15:05:14,603   process-id:120962 run_blocking_tasks: waiting for executor tasks
#
# 2020-10-22 15:05:14,604   process-id:121679   (task-0): passed args :['abc', 'l']
#
# 2020-10-22 15:05:14,606   process-id:121681   (task-1): passed args :['cde', 'n']
#
# 2020-10-22 15:05:14,607   process-id:121679   (task-0): running
#
# 2020-10-22 15:05:14,608   process-id:121681   (task-1): running
#
# 2020-10-22 15:05:14,608   process-id:121679 (sample_task): under task
#
# 2020-10-22 15:05:14,609   process-id:121681 (sample_task): under task
#
# 2020-10-22 15:05:14,610   process-id:121679   (task-0): done
#
# 2020-10-22 15:05:14,610   process-id:121681   (task-1): done
#
# ...

# %%
tasks_n_args_list =  [[NIO.sample_task, 'abc', 'l'], [NIO.sample_task2, 'cde', 'n']]
NIO.decorated_execute_tasklist(task_n_args_list=tasks_n_args_list,is_kernal_thread=True,)
# Out:
# 2020-10-22 15:05:14,627   process-id:120962    asyncio: Using selector: EpollSelector
#
# 2020-10-22 15:05:14,628   process-id:120962 execute_blocking_tasklist: starting
#
# 2020-10-22 15:05:14,628   process-id:120962 execute_blocking_tasklist: creating executor tasks
#
# 2020-10-22 15:05:14,656   process-id:120962 execute_blocking_tasklist: waiting for executor tasks
#
# 2020-10-22 15:05:14,658   process-id:121710   (task-0): passed args :['abc', 'l']
#
# 2020-10-22 15:05:14,659   process-id:121717   (task-1): passed args :['cde', 'n']
#
# 2020-10-22 15:05:14,661   process-id:121710   (task-0): running
#
# 2020-10-22 15:05:14,662   process-id:121717   (task-1): running
#
# 2020-10-22 15:05:14,662   process-id:121710 (sample_task): under task
#
# 2020-10-22 15:05:14,663   process-id:121717 (sample_task2): under task2
#
# 2020-10-22 15:05:14,663   process-id:121710   (task-0): done
#
# 2020-10-22 15:05:14,664   process-id:121717   (task-1): done
#
# ...

# %% [markdown]
# ### Custom tasks

# %%
def custom_task(arg1, arg2, arg3, arg4=-1):
    log = logging.getLogger('(custom_task)')
    log.info("under custom task")

    return str(arg1)+str(arg2)+str(arg3)+str(arg4)

# def custom_task(*arg):
#     log = logging.getLogger('(custom_task)')
#     log.info("under custom task")

#     return arg

tasks_n_args_list =  [
                        [NIO.sample_task, 'abc', 'l'], 
                        [NIO.sample_task2, 'cde', 'n'],
                        [custom_task, '0', '0', '1'],
                        [custom_task, '0', '1', '0'],
                        [custom_task, '0', '1', '1'],
                        [custom_task, '1', '0', '0'],
                        [custom_task, '1', '0', '1'],
                        [custom_task, '1', '1', '0'],
                        [custom_task, '1', '1', '1'],
                        [custom_task, '1', '0', '0', '0'],
                        [custom_task, '1', '0', '0', '1'],
                        [custom_task, '1', '0', '1', '0'],
                        [custom_task, '1', '0', '1', '1'],
                        [custom_task, '1', '1', '0', '0'],
                        [custom_task, '1', '1', '0', '1'],
                        [custom_task, '1', '1', '1', '0'],
                        [custom_task, '1', '1', '1', '1'],
                        
                     ]
NIO.decorated_execute_tasklist(task_n_args_list=tasks_n_args_list)
# Out:
# 2020-10-22 15:05:14,679:120962 MainThread asyncio: Using selector: EpollSelector
#
# 2020-10-22 15:05:14,681:120962 MainThread execute_blocking_tasklist: starting
#
# 2020-10-22 15:05:14,682:120962 MainThread execute_blocking_tasklist: creating executor tasks
#
# 2020-10-22 15:05:14,683:120962 ThreadPoolExecutor-2_0 (task-0): passed args :['abc', 'l']
#
# 2020-10-22 15:05:14,684:120962 ThreadPoolExecutor-2_1 (task-1): passed args :['cde', 'n']
#
# 2020-10-22 15:05:14,684:120962 ThreadPoolExecutor-2_2 (task-2): passed args :['0', '0', '1']
#
# 2020-10-22 15:05:14,684:120962 ThreadPoolExecutor-2_0 (task-0): running
#
# 2020-10-22 15:05:14,685:120962 ThreadPoolExecutor-2_3 (task-3): passed args :['0', '1', '0']
#
# 2020-10-22 15:05:14,686:120962 ThreadPoolExecutor-2_4 (task-4): passed args :['0', '1', '1']
#
# 2020-10-22 15:05:14,686:120962 ThreadPoolExecutor-2_5 (task-5): passed args :['1', '0', '0']
#
# 2020-10-22 15:05:14,686:120962 ThreadPoolExecutor-2_1 (task-1): running
#
# ...

# %%
tasks_n_args_list =  [
                        (NIO.sample_task, 'abc', 'l'), 
                        (NIO.sample_task2, 'cde', 'n'),
                        (custom_task, '0', '0', '1'),
                        (custom_task, '0', '1', '0'),
                        (custom_task, '0', '1', '1'),
                        (custom_task, '1', '0', '0'),
                        (custom_task, '1', '0', '1'),
                        (custom_task, '1', '1', '0'),
                        (custom_task, '1', '1', '1'),
                        (custom_task, '1', '0', '0', '0'),
                        (custom_task, '1', '0', '0', '1'),
                        (custom_task, '1', '0', '1', '0'),
                        (custom_task, '1', '0', '1', '1'),
                        (custom_task, '1', '1', '0', '0'),
                        (custom_task, '1', '1', '0', '1'),
                        (custom_task, '1', '1', '1', '0'),
                        (custom_task, '1', '1', '1', '1'),
                        
                     ]
NIO.decorated_execute_tasklist(task_n_args_list=tasks_n_args_list,)
# Out:
# 2020-10-22 15:05:14,755:120962 MainThread asyncio: Using selector: EpollSelector
#
# 2020-10-22 15:05:14,756:120962 MainThread execute_blocking_tasklist: starting
#
# 2020-10-22 15:05:14,757:120962 MainThread execute_blocking_tasklist: creating executor tasks
#
# 2020-10-22 15:05:14,757:120962 ThreadPoolExecutor-3_0 (task-0): passed args :('abc', 'l')
#
# 2020-10-22 15:05:14,758:120962 ThreadPoolExecutor-3_1 (task-1): passed args :('cde', 'n')
#
# 2020-10-22 15:05:14,758:120962 ThreadPoolExecutor-3_2 (task-2): passed args :('0', '0', '1')
#
# 2020-10-22 15:05:14,759:120962 ThreadPoolExecutor-3_3 (task-3): passed args :('0', '1', '0')
#
# 2020-10-22 15:05:14,760:120962 ThreadPoolExecutor-3_4 (task-4): passed args :('0', '1', '1')
#
# 2020-10-22 15:05:14,760:120962 ThreadPoolExecutor-3_0 (task-0): running
#
# 2020-10-22 15:05:14,760:120962 ThreadPoolExecutor-3_5 (task-5): passed args :('1', '0', '0')
#
# ...

# %%
NIO.decorated_execute_tasklist(task_n_args_list=tasks_n_args_list,is_kernal_thread=True,)
# Out:
# 2020-10-22 15:05:14,829   process-id:120962    asyncio: Using selector: EpollSelector
#
# 2020-10-22 15:05:14,830   process-id:120962 execute_blocking_tasklist: starting
#
# 2020-10-22 15:05:14,831   process-id:120962 execute_blocking_tasklist: creating executor tasks
#
# 2020-10-22 15:05:14,862   process-id:120962 execute_blocking_tasklist: waiting for executor tasks
#
# 2020-10-22 15:05:14,864   process-id:121944   (task-1): passed args :('cde', 'n')
#
# 2020-10-22 15:05:14,864   process-id:121943   (task-0): passed args :('abc', 'l')
#
# 2020-10-22 15:05:14,864   process-id:121951   (task-2): passed args :('0', '0', '1')
#
# 2020-10-22 15:05:14,865   process-id:121955   (task-3): passed args :('0', '1', '0')
#
# 2020-10-22 15:05:14,867   process-id:121943   (task-0): running
#
# 2020-10-22 15:05:14,865   process-id:121959   (task-4): passed args :('0', '1', '1')
#
# 2020-10-22 15:05:14,867   process-id:121944   (task-1): running
#
# ...

# %%
tasks_n_args_list=         [ 
                               [
                                   [
                                    [NIO.sample_task, 'abc', 'l'], 
                                    [NIO.sample_task2, 'cde', 'n'], 
                                   ],
                               ],
                               [ 
                                   [
                                    [custom_task, '1', '0', '0', '0'],
                                    [custom_task, '1', '0', '0', '1'],
                                    [custom_task, '1', '0', '1', '0'],
                                    [custom_task, '1', '0', '1', '1'],
                                    [custom_task, '1', '1', '0', '0'],
                                    [custom_task, '1', '1', '0', '1'],
                                    [custom_task, '1', '1', '1', '0'],
                                    [custom_task, '1', '1', '1', '1'],
                                   ],
                               ],
                               [
                                   [
                                    [custom_task, '1', '0', '0', '0'],
                                    [custom_task, '1', '0', '0', '1'],
                                    [custom_task, '1', '0', '1', '0'],
                                    [custom_task, '1', '0', '1', '1'],
                                    [custom_task, '1', '1', '0', '0'],
                                    [custom_task, '1', '1', '0', '1'],
                                    [custom_task, '1', '1', '1', '0'],
                                    [custom_task, '1', '1', '1', '1'],
                                   ],
                               ],
                       ]
NIO.run_using_process_of_threads(tasks_n_args_list, max_proc_workers=1)
# Out:
# 2020-10-22 15:05:14,914   process-id:120962    asyncio: Using selector: EpollSelector
#
# 2020-10-22 15:05:14,915   process-id:120962 run_blocking_tasks: starting
#
# 2020-10-22 15:05:14,915   process-id:120962 run_blocking_tasks: creating executor tasks
#
# 2020-10-22 15:05:14,920   process-id:120962 run_blocking_tasks: waiting for executor tasks
#
# 2020-10-22 15:05:14,922   process-id:122115   (task-0): passed args :[[[<bound method NIO.sample_task of <class 'libs.nio_executor.NIO'>>, 'abc', 'l'], [<bound method NIO.sample_task2 of <class 'libs.nio_executor.NIO'>>, 'cde', 'n']]]
#
# 2020-10-22 15:05:14,924   process-id:122115   (task-0): running
#
# 2020-10-22 15:05:14,926:122115 MainThread asyncio: Using selector: EpollSelector
#
# 2020-10-22 15:05:14,927:122115 MainThread execute_blocking_tasklist: starting
#
# 2020-10-22 15:05:14,928:122115 MainThread execute_blocking_tasklist: creating executor tasks
#
# ...

# %%
tasks_n_args_list1=[
                    [NIO.sample_task, 'abc', 'l'], 
                    [NIO.sample_task2, 'cde', 'n'], 
                   ]
tasks_n_args_list2=[
                    [custom_task, '0', '0', '1'],
                    [custom_task, '0', '1', '0'],
                    [custom_task, '0', '1', '1'],
                    [custom_task, '1', '0', '0'],
                    [custom_task, '1', '0', '1'],
                    [custom_task, '1', '1', '0'],
                    [custom_task, '1', '1', '1'],
                   ]
tasks_n_args_list3=[
                    [custom_task, '1', '0', '0', '0'],
                    [custom_task, '1', '0', '0', '1'],
                    [custom_task, '1', '0', '1', '0'],
                    [custom_task, '1', '0', '1', '1'],
                    [custom_task, '1', '1', '0', '0'],
                    [custom_task, '1', '1', '0', '1'],
                    [custom_task, '1', '1', '1', '0'],
                    [custom_task, '1', '1', '1', '1'],
                    ]


tasks_n_args_list=    [ 
                        [tasks_n_args_list1],
                        [tasks_n_args_list2],
                        [tasks_n_args_list3]
                       ]
NIO.run_using_process_of_threads(tasks_n_args_list)
# Out:
# 2020-10-22 15:05:15,065   process-id:120962    asyncio: Using selector: EpollSelector
#
# 2020-10-22 15:05:15,067   process-id:120962 run_blocking_tasks: starting
#
# 2020-10-22 15:05:15,067   process-id:120962 run_blocking_tasks: creating executor tasks
#
# 2020-10-22 15:05:15,098   process-id:120962 run_blocking_tasks: waiting for executor tasks
#
# 2020-10-22 15:05:15,100   process-id:122390   (task-0): passed args :[[[<bound method NIO.sample_task of <class 'libs.nio_executor.NIO'>>, 'abc', 'l'], [<bound method NIO.sample_task2 of <class 'libs.nio_executor.NIO'>>, 'cde', 'n']]]
#
# ...

# %%
tasks_n_args_list=    [ 
                        [tasks_n_args_list1,2],
                        [tasks_n_args_list2,4],
                        [tasks_n_args_list3,5]
                       ]
NIO.run_using_process_of_threads(tasks_n_args_list,)
# Out:
# 2020-10-22 15:05:15,182   process-id:120962    asyncio: Using selector: EpollSelector
#
# 2020-10-22 15:05:15,183   process-id:120962 run_blocking_tasks: starting
#
# 2020-10-22 15:05:15,184   process-id:120962 run_blocking_tasks: creating executor tasks
#
# 2020-10-22 15:05:15,212   process-id:120962 run_blocking_tasks: waiting for executor tasks
#
# 2020-10-22 15:05:15,215   process-id:122649   (task-0): passed args :[[[<bound method NIO.sample_task of <class 'libs.nio_executor.NIO'>>, 'abc', 'l'], [<bound method NIO.sample_task2 of <class 'libs.nio_executor.NIO'>>, 'cde', 'n']], 2]
#
# ...

# %%
collected = NIO.run_using_process_of_threads(tasks_n_args_list, max_proc_workers=2)
# Out:
# 2020-10-22 16:27:01,748   process-id:120962    asyncio: Using selector: EpollSelector
#
# 2020-10-22 16:27:01,749   process-id:120962 run_blocking_tasks: starting
#
# 2020-10-22 16:27:01,750   process-id:120962 run_blocking_tasks: creating executor tasks
#
# 2020-10-22 16:27:01,758   process-id:120962 run_blocking_tasks: waiting for executor tasks
#
# 2020-10-22 16:27:01,762   process-id:55166   (task-0): passed args :[[[<bound method NIO.sample_task of <class 'libs.nio_executor.NIO'>>, 'abc', 'l'], [<bound method NIO.sample_task2 of <class 'libs.nio_executor.NIO'>>, 'cde', 'n']], 2]
#
# ...

# %%
# collected
[item for item in collected]
#[ r for item in collected for r in item['result']]
#[ r['result'] for item in collected for r in item['result']]
#[ (item['id'], r['id'], r['result']) for item in collected for r in item['result']]
#[ res for item in collected for r in item['result'] for res in r['result'] ]
# Out:
# [{'id': 'task-2',
#   'task': <bound method NIO.__execute_thread_pool_inernal__ of <class 'libs.nio_executor.NIO'>>,
#   'args': [[[<function __main__.custom_task(arg1, arg2, arg3, arg4=-1)>,
#      '1',
#      '0',
#      '0',
#      '0'],
#     [<function __main__.custom_task(arg1, arg2, arg3, arg4=-1)>,
#      '1',
#      '0',
#      '0',
#      '1'],
#     [<function __main__.custom_task(arg1, arg2, arg3, arg4=-1)>,
#      '1',
#      '0',
#      '1',
#      '0'],
#     [<function __main__.custom_task(arg1, arg2, arg3, arg4=-1)>,
#      '1',
#      '0',
#      '1',
#      '1'],
#     [<function __main__.custom_task(arg1, arg2, arg3, arg4=-1)>,
#      '1',
#      '1',
#      '0',
#      '0'],
#     [<function __main__.custom_task(arg1, arg2, arg3, arg4=-1)>,
#      '1',
#      '1',
#      '0',
#      '1'],
#     [<function __main__.custom_task(arg1, arg2, arg3, arg4=-1)>,
#      '1',
#      '1',
#      '1',
#      '0'],
# ...

# %%
def sample_generator():
    for i in range(15):
#         time.sleep(10-i)
        yield i


def sample_task3(arg):
    log = logging.getLogger('(sample_task3:{})'.format(str(arg)))
    r = Random()
    v = r.randrange(0,9)
    log.info(v)
    time.sleep(10-v)
    log.info("under sample_task3")

    return arg

# %%
collected = NIO.run_with_args_generator(task=sample_task3, args_generator=sample_generator())
collected
# Out:
# 2020-10-22 15:05:15,413 DEBUG asyncio: Using selector: EpollSelector
# 2020-10-22 15:05:15,414 INFO run_blocking_tasks: starting
# 2020-10-22 15:05:15,415 INFO run_blocking_tasks: creating executor tasks
# 2020-10-22 15:05:15,416 INFO (task-0): passed args :0
# 2020-10-22 15:05:15,417 INFO (task-1): passed args :1
# 2020-10-22 15:05:15,417 INFO (task-2): passed args :2
# 2020-10-22 15:05:15,418 INFO (task-0): running
# 2020-10-22 15:05:15,418 INFO (task-1): running
# 2020-10-22 15:05:15,419 INFO (task-3): passed args :3
# 2020-10-22 15:05:15,420 INFO (task-4): passed args :4
# 2020-10-22 15:05:15,420 INFO (task-2): running
# 2020-10-22 15:05:15,421 INFO (task-5): passed args :5
# 2020-10-22 15:05:15,422 INFO (task-6): passed args :6
# 2020-10-22 15:05:15,422 INFO (task-7): passed args :7
# 2020-10-22 15:05:15,423 INFO (task-8): passed args :8
# 2020-10-22 15:05:15,423 INFO (sample_task3:0): 2
# 2020-10-22 15:05:15,424 INFO (task-9): passed args :9
# ...

# %%
NIO.decorated_run_with_args_generator(task=NIO.sample_task3, args_generator=NIO.sample_generator())
# Out:
# 2020-10-22 15:05:29,466:120962 MainThread asyncio: Using selector: EpollSelector
#
# 2020-10-22 15:05:29,467:120962 MainThread run_blocking_tasks: starting
#
# 2020-10-22 15:05:29,468:120962 MainThread run_blocking_tasks: creating executor tasks
#
# 2020-10-22 15:05:29,468:120962 ThreadPoolExecutor-5_0 (task-0): passed args :[0]
#
# 2020-10-22 15:05:29,469:120962 ThreadPoolExecutor-5_1 (task-1): passed args :[1]
#
# 2020-10-22 15:05:29,469:120962 ThreadPoolExecutor-5_2 (task-2): passed args :[2]
#
# 2020-10-22 15:05:29,469:120962 ThreadPoolExecutor-5_0 (task-0): running
#
# 2020-10-22 15:05:29,470:120962 ThreadPoolExecutor-5_3 (task-3): passed args :[3]
#
# 2020-10-22 15:05:29,470:120962 ThreadPoolExecutor-5_4 (task-4): passed args :[4]
#
# 2020-10-22 15:05:29,471:120962 MainThread run_blocking_tasks: waiting for executor tasks
#
# 2020-10-22 15:05:29,471:120962 ThreadPoolExecutor-5_1 (task-1): running
#
# 2020-10-22 15:05:29,472:120962 ThreadPoolExecutor-5_2 (task-2): running
#
# ...

# %%
def sample_task_4(*args):
    log = logging.getLogger('(sample_task4)')
    time.sleep(10)
    log.info("under task3")

    return args

tasks_dict = {'task_1':['k', 'l'], 'task_2':['m', 'n']}
#result = {'taskId':'', 'task':'', 'args': , :"result", error}

collected = NIO.execute_io(func=sample_task_4, max_workers=10, is_kernal_thread=True, **tasks_dict)
collected
# Out:
# 2020-10-22 15:05:50,119 DEBUG asyncio: Using selector: EpollSelector
# 2020-10-22 15:05:50,120 INFO run_blocking_tasks: starting
# 2020-10-22 15:05:50,120 INFO run_blocking_tasks: creating executor tasks
# 2020-10-22 15:05:50,151 INFO run_blocking_tasks: waiting for executor tasks
# 2020-10-22 15:05:50,153 INFO (task_1): passed args :['k', 'l']
# 2020-10-22 15:05:50,154 INFO (task_2): passed args :['m', 'n']
# 2020-10-22 15:05:50,156 INFO (task_1): running
# 2020-10-22 15:05:50,157 INFO (task_2): running
# 2020-10-22 15:06:00,168 INFO (sample_task4): under task3
# 2020-10-22 15:06:00,168 INFO (sample_task4): under task3
# 2020-10-22 15:06:00,169 INFO (task_1): done
# 2020-10-22 15:06:00,169 INFO (task_2): done
# ...
