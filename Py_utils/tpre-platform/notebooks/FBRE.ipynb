# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
import os
import numpy as np
import pandas as pd
import matplotlib as mpl
#from matplotlib.ticker import FuncFormatter
#import matplotlib.pyplot as plt
#import altair as alt
from IPython.display import HTML, display
#from hive_query import hive_query
from dask.multiprocessing import get
import requests
import json
from concurrent.futures import ThreadPoolExecutor
import hashlib
import io
from functools import partial
import time
import datetime
import hashlib
import logging
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(threadName)-12.12s] [%(levelname)-5.5s]  %(message)s",
    handlers=[
        #logging.FileHandler("{0}/{1}.log".format(logPath, fileName)),
        logging.StreamHandler()
    ])

# %%
# !pwd
# Out:
# /home/vbhargava/fb_v8.1/msaction_backend/common/BU3.0_core/util/Py_utils/tpre-platform4/notebooks

# %%
sys.path.append("/home/vbhargava/fb_v8.1/msaction_backend/common/BU3.0_core/util/Py_utils/tpre-platform4/fb")

# %%
# !ls -lrt /home/vbhargava/fb_v8.1/pc
# Out:
# total 8
# drwxrwxr-x 2 vbhargava vbhargava 4096 Mar 11 06:17 ctam_v81_testing
# -rwxrwxr-x 1 vbhargava vbhargava 3154 Mar 31 20:15 platform_config.xml

# %%
config = '/home/vbhargava/fb_v8.1/pc/platform_config.xml'
# !cat $config
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <configroot version="8.1">
#   <set>
#     <name>PLATFORM</name>
#     <stringval>qubole</stringval>
#   </set>
#   <set>
#     <name>CLIENT_TYPE</name>
#     <stringval>abc</stringval>
#   </set>
#   <altiscale_settings>
#     <set>
#       <name>hive_cmd</name>
#       <stringval>/opt/hive/bin/hive</stringval>
#     </set>
#     <set>
#       <name>hadoop_cmd</name>
#       <stringval>/opt/hadoop/bin/hadoop</stringval>
#     </set>
#     <set type="derived">
#       <name>CLIENT_WAREHOUSE_LOC</name>
#       <stringval/>
#     </set>
#     <set type="derived">
#       <name>JARLOCATION</name>
#       <stringval/>
#     </set>
#   </altiscale_settings>
#   <qubole_settings>
#     <set>
#       <name>qds_cmd</name>
#       <stringval>/usr/local/bin/qds.py</stringval>
#     </set>
#     <set>
#       <name>s3cmd</name>
#       <stringval>/usr/local/bin/s3cmd</stringval>
#     </set>
#     <set>
#       <name>s3_location</name>
# ...

# %%
print('System path:'+ str(sys.path))
# Out:
# System path:['/home/vbhargava/fb_v8.1/msaction_backend/common/BU3.0_core/util/Py_utils/tpre-platform4/notebooks', '/home/vbhargava/raj_fb/anaconda3/lib/python37.zip', '/home/vbhargava/raj_fb/anaconda3/lib/python3.7', '/home/vbhargava/raj_fb/anaconda3/lib/python3.7/lib-dynload', '', '/home/vbhargava/raj_fb/anaconda3/lib/python3.7/site-packages', '/home/vbhargava/raj_fb/anaconda3/lib/python3.7/site-packages/IPython/extensions', '/home/vbhargava/.ipython', '/home/vbhargava/fb_v8.1/msaction_backend/common/BU3.0_core/util/Py_utils/tpre-platform4/fb']

# %%
ls /home/vbhargava/fb_v8.1/msaction_backend/common/BU3.0_core/util/Py_utils/tpre-platform4/fb
# Out:
# fbre.py  __pycache__/

# %%
import inspect
import fbre as fbre

# %%
inspect.getmembers(fbre, inspect.isfunction)
# Out:
# [('attach_event_set',
#   <function conv_api_conn.attach_event_set(access_token, event_set_id, business_id, account_id)>),
#  ('copy_fb_report_to_s3',
#   <function fbre.copy_fb_report_to_s3(config, destpath, s3_loc=None)>),
#  ('create_event_set',
#   <function conv_api_conn.create_event_set(access_token, business_id, set_name, description)>),
#  ('create_parser', <function fbre.create_parser()>),
#  ('download_report',
#   <function fbre.download_report(urls, destpath, **kwargs)>),
#  ('download_report_files',
#   <function conv_api_conn.download_report_files(urls, path='./', check_sizes=True)>),
#  ('dump_fb_report_to_s3',
#   <function fbre.dump_fb_report_to_s3(config, destpath, s3_loc=None)>),
#  ('get_report_urls',
#   <function fbre.get_report_urls(access_token, business_id, pixel_id, request_ids)>),
#  ('get_reports_urls',
#   <function conv_api_conn.get_reports_urls(access_token, business_id, pixel_id, request_id, **kwargs)>),
# ...

# %%
access_token = "EAAZAuVvcfbzIBAN7eEabFBtQglFmQZBXu3mdI6vveFfZBVQF7HkSp8Jq7FcekmODGZCEXZBcU3zsosT8JuTpReOcqOwcezuWuxXgAiPCi7d1b2nxZCR3QAjhxa2U7GRNuY5LvtkdpZBJBZB4EZB0dPBaKdPBIUNBAZBIYfTV4n8zhO6chwL6CI5LKnmkmukLaqWRUZD"
business_id = "1386462108046405"
account_id = "2119137694778839" #CTAM
set_name = "fbre_ctam_v1"
description = "fbre_ctam_v1_desc"
pixel_id = '1413784998747251' # CTAM
start_date = '2018-08-05'
end_date = '2018-08-11'
tag = "fbre_ctam_v1_tag"
table = 'coeffstack_p2_mspnightly_ctam_v81_testing.coeffstack_backbone'
upload_file_path = None
event_set_id = None
client_s3_loc = "s3://qubole-nightly/warehouse/ctam_v81_testing"

# %%
res_upload = fbre.upload(tag, config, access_token, business_id, account_id, table, set_name, description, start_date, end_date, upload_file_path, event_set_id=event_set_id)

# %%
res_upload
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-9d8589e6a445> in <module>
# ----> 1 res_upload
#
# NameError: name 'res_upload' is not defined

# %%
request_ids = fbre.upload_evalution(tag, config, access_token, business_id, start_date, end_date, client_s3_loc)
# Out:
# 2019-05-07 11:53:49,070 [MainThread  ] [INFO ]  Request run URL: https://graph.facebook.com/v3.1/1386462108046405/upload_event
# 2019-05-07 11:53:49,073 [MainThread  ] [INFO ]  Request run params: {'upload_tag': 'fbre_ctam_v1_tag', 'conversion_start_date': '2018-08-05', 'conversion_end_date': '2018-08-11', 'lookback_window': 'DAYS60', 'match_universe': 'FULL', 'timezone': 'TZ_AMERICA_LOS_ANGELES', 'aggregation_level': 'WEEKLY', 'access_token': 'EAAZAuVvcfbzIBAN7eEabFBtQglFmQZBXu3mdI6vveFfZBVQF7HkSp8Jq7FcekmODGZCEXZBcU3zsosT8JuTpReOcqOwcezuWuxXgAiPCi7d1b2nxZCR3QAjhxa2U7GRNuY5LvtkdpZBJBZB4EZB0dPBaKdPBIUNBAZBIYfTV4n8zhO6chwL6CI5LKnmkmukLaqWRUZD'}
# 2019-05-07 11:53:49,327 [MainThread  ] [INFO ]  response: {'id': '476855239787020', 'date_start': '2018-08-05', 'date_end': '2018-08-11'}
# ...

# %%
request_ids
# Out:
# ['476855239787020']

# %%
urls = fbre.get_report_urls(access_token, business_id, pixel_id, request_ids)
urls
# Out:
# 2019-05-07 12:55:05,164 [MainThread  ] [INFO ]  Get reports URL: https://graph.facebook.com/v3.1/1386462108046405/measurement_reports
# 2019-05-07 12:55:05,166 [MainThread  ] [INFO ]  Get reports params: {'fields': '["download_urls", "metadata"]', 'report_type': 'third_party_mta_report', 'access_token': 'EAAZAuVvcfbzIBAN7eEabFBtQglFmQZBXu3mdI6vveFfZBVQF7HkSp8Jq7FcekmODGZCEXZBcU3zsosT8JuTpReOcqOwcezuWuxXgAiPCi7d1b2nxZCR3QAjhxa2U7GRNuY5LvtkdpZBJBZB4EZB0dPBaKdPBIUNBAZBIYfTV4n8zhO6chwL6CI5LKnmkmukLaqWRUZD', 'filters': '[{"key": "account", "value": "1413784998747251"}, {"key": "name", "value": "476855239787020", "comparison": "in"}]'}
# ***** Working on: 476855239787020
# {
#   "data": []
# }
# {}

# %%
#ATT
business_id = "1386462108046405"
pixel_id = '128900881029137'
#request_ids = ['848478348835361']
request_ids = ['476855239787020']

urls = fbre.get_report_urls(access_token, business_id, pixel_id, request_ids)
urls
# Out:
# 2019-05-10 06:01:18,629 [MainThread  ] [INFO ]  Get reports URL: https://graph.facebook.com/v3.1/1386462108046405/measurement_reports
# 2019-05-10 06:01:18,631 [MainThread  ] [INFO ]  Get reports params: {'fields': '["download_urls", "metadata"]', 'report_type': 'third_party_mta_report', 'access_token': 'EAAZAuVvcfbzIBAN7eEabFBtQglFmQZBXu3mdI6vveFfZBVQF7HkSp8Jq7FcekmODGZCEXZBcU3zsosT8JuTpReOcqOwcezuWuxXgAiPCi7d1b2nxZCR3QAjhxa2U7GRNuY5LvtkdpZBJBZB4EZB0dPBaKdPBIUNBAZBIYfTV4n8zhO6chwL6CI5LKnmkmukLaqWRUZD', 'filters': '[{"key": "account", "value": "128900881029137"}, {"key": "name", "value": "476855239787020", "comparison": "in"}]'}
# ***** Working on: 476855239787020
# 2019-05-10 06:01:23,870 [MainThread  ] [INFO ]  Response report urls: {}
# {
#   "data": []
# }
# {}

# %%
len(urls)
# Out:
# 0

# %%
fb_report_path="/tmp/fb_report/ctam/p2/report/"
fbre.download_report(urls, fb_report_path)
# Out:
# 2019-05-07 13:30:39,644 [MainThread  ] [INFO ]  Downloaded 2019-03-30-848478348835361-128900881029137-cohort_summary_1.csv.gpg.gz, size 20321039
# 2019-05-07 13:30:40,191 [MainThread  ] [INFO ]  Downloaded 2019-03-30-848478348835361-128900881029137-cohort_summary_10.csv.gpg.gz, size 16659901
# 2019-05-07 13:30:40,698 [MainThread  ] [INFO ]  Downloaded 2019-03-30-848478348835361-128900881029137-cohort_summary_100.csv.gpg.gz, size 8633522
# 2019-05-07 13:30:40,960 [MainThread  ] [INFO ]  Downloaded 2019-03-30-848478348835361-128900881029137-cohort_membership_10.csv.gpg.gz, size 3345271
# 2019-05-07 13:30:41,097 [MainThread  ] [INFO ]  Downloaded 2019-03-30-848478348835361-128900881029137-cohort_metrics_10.csv.gpg.gz, size 181262
# 2019-05-07 13:30:41,292 [MainThread  ] [INFO ]  Downloaded 2019-03-30-848478348835361-128900881029137-cohort_metrics_1.csv.gpg.gz, size 1874733
# ...

# %%
# !ls -l {fb_report_path}
# Out:
# total 62644
# -rw-rw-r-- 1 vbhargava vbhargava  3218268 May  7 13:30 2019-03-30-848478348835361-128900881029137-cohort_membership_1000.csv.gpg
# -rw-rw-r-- 1 vbhargava vbhargava  3257014 May  7 13:30 2019-03-30-848478348835361-128900881029137-cohort_membership_100.csv.gpg
# -rw-rw-r-- 1 vbhargava vbhargava  3344610 May  7 13:30 2019-03-30-848478348835361-128900881029137-cohort_membership_10.csv.gpg
# -rw-rw-r-- 1 vbhargava vbhargava  3550237 May  7 13:30 2019-03-30-848478348835361-128900881029137-cohort_membership_1.csv.gpg
# -rw-rw-r-- 1 vbhargava vbhargava     2485 May  7 13:30 2019-03-30-848478348835361-128900881029137-cohort_metrics_1000.csv.gpg
# -rw-rw-r-- 1 vbhargava vbhargava    18457 May  7 13:30 2019-03-30-848478348835361-128900881029137-cohort_metrics_100.csv.gpg
# -rw-rw-r-- 1 vbhargava vbhargava   181089 May  7 13:30 2019-03-30-848478348835361-128900881029137-cohort_metrics_10.csv.gpg
# ...

# %%
os.makedirs(fb_report_path, exist_ok=True)

# %%
# !ls -l /home/vbhargava/fb_v8.1/reports/unzipped/decrypt
# Out:
# total 595292
# -rw-rw-r-- 1 vbhargava vbhargava   9702400 May  2 20:48 2019-03-30-848478348835361-128900881029137-cohort_membership_1000.csv
# -rw-rw-r-- 1 vbhargava vbhargava   9827200 May  2 20:48 2019-03-30-848478348835361-128900881029137-cohort_membership_100.csv
# -rw-rw-r-- 1 vbhargava vbhargava   9952900 May  2 20:48 2019-03-30-848478348835361-128900881029137-cohort_membership_10.csv
# -rw-rw-r-- 1 vbhargava vbhargava  10078690 May  2 20:48 2019-03-30-848478348835361-128900881029137-cohort_membership_1.csv
# -rw-rw-r-- 1 vbhargava vbhargava      7549 May  2 20:48 2019-03-30-848478348835361-128900881029137-cohort_metrics_1000.csv
# -rw-rw-r-- 1 vbhargava vbhargava     76549 May  2 20:48 2019-03-30-848478348835361-128900881029137-cohort_metrics_100.csv
# -rw-rw-r-- 1 vbhargava vbhargava    777829 May  2 20:48 2019-03-30-848478348835361-128900881029137-cohort_metrics_10.csv
# ...

# %%
import glob
from pathlib import Path
def copy_fb_report_to_s3(config, destpath, staging_s3_upload=None):
    cohort_size = '100'
    schema =  {
        'membership': ('pixel_id', 'hh_id', 'cohort_number', 'request_id'),
        'metric': ('pixel_id', 'cohort_number', 'click_value', 'imp_value', 'request_id'),
        'summary': ('pixel_id', 'account_id', 'campaign_id', 'adset_id', 'ad_id', 'click_count', 'imps_count', 'request_id'),
        'taxonomy': ('pixel_id', 'account_id', 'account_name', 'campaign_id', 'campaign_name', 'adset_id', 'adset_name', 'ad_id', 'ad_name', 'click_or_imp', 'all_events', 'successful_events', 'request_id')
    }
    
    if staging_s3_upload is not None:
        staging_s3 = Path(os.path.abspath(staging_s3_upload))
        staging_s3_upload_path = (staging_s3 / '..' / 'utils' / 'bash_utils').resolve()
    
    for ftype in schema:
        print("*** Working on: {}".format(ftype))
        s3_loc_path = None
        if s3_loc is not None:
            s3_loc_path = s3_loc+"/tpre_results/"+ftype+"/"
        path = os.path.join(destpath, "/decrypt")
        search_path = os.path.join(path, "*{}_{}*.csv".format(ftype, cohort_size))
        print(search_path)
        files = glob.glob(search_path)
        print(files)
        for file_path in files:
            #TODO send to S3
            s3_put(config, file_path, s3_loc_path)

# %%
import glob
from pathlib import Path
import tempfile
import shutil
destpath = "/home/vbhargava/fb_v8.1/reports/unzipped"
staging_s3_upload = "/home/vbhargava/fb_v8.1/reports"
staging_s3_upload_tmp = tempfile.TemporaryDirectory(dir = staging_s3_upload)
staging_s3_upload_tmp
s3_loc = client_s3_loc

# %%
client_s3_loc = "s3://qubole-nightly/warehouse/ctam_v81_testing"
client_s3_loc
fbre.dump_fb_report_to_s3(config, destpath, client_s3_loc)
# Out:
# /home/vbhargava/fb_v8.1/reports/unzipped/s3_staging
# ...
# *** Working on: membership
# /home/vbhargava/fb_v8.1/reports/unzipped/decrypt/*membership*100.csv
# ['/home/vbhargava/fb_v8.1/reports/unzipped/decrypt/2019-03-30-848478348835361-128900881029137-cohort_membership_100.csv']
# /home/vbhargava/fb_v8.1/reports/unzipped/s3_staging/membership
# s3://qubole-nightly/warehouse/ctam_v81_testing/tpre_results/membership/
# {'s3_location': 's3://qubole-nightly/warehouse/', 'token': 'e1b02a0b8d5443c1aafba175312842f6bd833247361048438f37df2cedd51943', 'url': 'https://api.qubole.com/api', 'cluster': 'Nightly-Dnow', 'access_key': 'AKIAJSZT7LGTGV4UYU7Q', 'secret_key': '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'}
# stdout:
# Completed 256.0 KiB/37.7 MiB (1.6 MiB/s) with 4 file(s) remaining
# Completed 512.0 KiB/37.7 MiB (3.1 MiB/s) with 4 file(s) remaining
# Completed 768.0 KiB/37.7 MiB (4.5 MiB/s) with 4 file(s) remaining
# Completed 1.0 MiB/37.7 MiB (5.6 MiB/s) with 4 file(s) remaining
# ...

# %%
import os
cohort_size = '100'
schema =  {
    'membership': ('pixel_id', 'hh_id', 'cohort_number', 'request_id'),
    'metric': ('pixel_id', 'cohort_number', 'click_value', 'imp_value', 'request_id'),
    'summary': ('pixel_id', 'account_id', 'campaign_id', 'adset_id', 'ad_id', 'click_count', 'imps_count', 'request_id'),
    'taxonomy': ('pixel_id', 'account_id', 'account_name', 'campaign_id', 'campaign_name', 'adset_id', 'adset_name', 'ad_id', 'ad_name', 'click_or_imp', 'all_events', 'successful_events', 'request_id')
}
path = os.path.join(destpath, "decrypt") 
s3_staging = os.path.join(destpath, "s3_staging") 
os.makedirs(s3_staging, exist_ok=True)
print(s3_staging)
for ftype in schema:
    os.makedirs(os.path.join(s3_staging, ftype), exist_ok=True)

for ftype in schema:
        print("=================================================")
        #print("*** Working on: {}".format(ftype))
#         if ftype not in ("taxonomy",):
#             search_path = os.path.join(path, "*{}*{}.csv".format(ftype,cohort_size))
#         else:
#             search_path = os.path.join(path, "*{}*.csv".format(ftype))
        search_path = os.path.join(path, "*{}*.csv".format(ftype))
        print(search_path)
        files = glob.glob(search_path)
        print(files)
        ftype_s3_staging = os.path.join(s3_staging, ftype)
        print(ftype_s3_staging)
        
        for file_path in files:
            shutil.copy(file_path, ftype_s3_staging, follow_symlinks=False)
            #TODO send to S3
            #s3_put(config, file_path, s3_loc_path)
        s3_loc_path = "{}/tpre_results3/{}/".format(s3_loc,ftype)
        print(s3_loc_path)
        s3_put_files_recursive(config, ftype_s3_staging, s3_loc_path)
# Out:
# /home/vbhargava/fb_v8.1/reports/unzipped/s3_staging
# ...
# /home/vbhargava/fb_v8.1/reports/unzipped/decrypt/*membership*.csv
# ['/home/vbhargava/fb_v8.1/reports/unzipped/decrypt/2019-03-30-848478348835361-128900881029137-cohort_membership_10.csv', '/home/vbhargava/fb_v8.1/reports/unzipped/decrypt/2019-03-30-848478348835361-128900881029137-cohort_membership_1.csv', '/home/vbhargava/fb_v8.1/reports/unzipped/decrypt/2019-03-30-848478348835361-128900881029137-cohort_membership_100.csv', '/home/vbhargava/fb_v8.1/reports/unzipped/decrypt/2019-03-30-848478348835361-128900881029137-cohort_membership_1000.csv']
# /home/vbhargava/fb_v8.1/reports/unzipped/s3_staging/membership
# s3://qubole-nightly/warehouse/ctam_v81_testing/tpre_results3/membership/
# ...

# %%
# !ls  /home/vbhargava/fb_v8.1/reports/unzipped/s3_staging/membership
# Out:
# 2019-03-30-848478348835361-128900881029137-cohort_membership_100.csv

# %%
import subprocess
import os, sys
from threading import current_thread
from multiprocessing import current_process
import pandas as pd
import logging
sys.path.append("/home/vbhargava/fb_v8.1/msaction_backend/common/BU3.0_core/util/Py_utils/utils/hive_query/hive_query.py")
from hive_query import parse_config
def s3_put_files_recursive(
        config,
        dir_for_s3,
        s3_location=None,
        debug=False,
        print_stderr=False,
        **kwargs):
    """Executes a s3 cmd using aws s3 CLI, captures stdout into a pd.DataFrame
    and optionally prints stderr into the screen

    Parameters
    ---------
    df : pandas.DataFrame
        DataFrame to be uploaded to Hive
    config : string
        Path to `platform_config.xml` file for the client for which the table will be created
    debug : boolean (Optional)
        If True, prints debug info to stdout, default: False
    print_stderr : boolean (Optional)
        If True, prints stderr into screen, default: False
    **kwargs will be directly passed to hive_query()
    """
   # assert isinstance(df, pd.DataFrame), "df must be a pandas.DataFrame"
    assert isinstance(debug, bool), "debug must be boolean"
    assert isinstance(print_stderr, bool), "print_stderr must be boolean"

    # Parse config file
    platform, config_values = parse_config(config)
    print(config_values)
    assert platform.lower() in ('emr', 'qubole'), "Only EMR or Qubole platforms accepted"

    os.environ['AWS_ACCESS_KEY_ID'] = config_values['access_key']
    os.environ['AWS_SECRET_ACCESS_KEY'] = config_values['secret_key']
    
    if s3_location is None:
        s3_location = config_values['s3_location']
    #call_copy_data = f"aws s3 rm {s3_location} --recursive; aws s3 cp {fname} {s3_location}"
    call_copy_data = f"aws s3 cp {dir_for_s3} {s3_location} --recursive"
    p = subprocess.Popen(
        call_copy_data,
        shell=True,
        executable='/bin/bash',
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        universal_newlines=True,
        encoding='utf-8'
    )
    print("stdout:\n" + p.stdout.read())
    print("stderr:\n" + p.stderr.read())

# %%
s3_put_files_recursive(config, "/tmp/fb_report/ctam_v81_testing/p2/report//fb_reports_1557423166/downloads/s3_staging/taxonomy", "s3://qubole-nightly/warehouse/ctam_v81_testing/tpre_results/taxonomy/")
# Out:
# {'s3_location': 's3://qubole-nightly/warehouse/', 'token': 'e1b02a0b8d5443c1aafba175312842f6bd833247361048438f37df2cedd51943', 'url': 'https://api.qubole.com/api', 'cluster': 'Nightly-Dnow', 'access_key': 'AKIAJSZT7LGTGV4UYU7Q', 'secret_key': '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'}
# stdout:
# Completed 256.0 KiB/2.6 MiB (2.5 MiB/s) with 1 file(s) remaining
# Completed 512.0 KiB/2.6 MiB (4.8 MiB/s) with 1 file(s) remaining
# Completed 768.0 KiB/2.6 MiB (7.0 MiB/s) with 1 file(s) remaining
# Completed 1.0 MiB/2.6 MiB (9.2 MiB/s) with 1 file(s) remaining
# Completed 1.2 MiB/2.6 MiB (11.2 MiB/s) with 1 file(s) remaining
# Completed 1.5 MiB/2.6 MiB (13.1 MiB/s) with 1 file(s) remaining
# Completed 1.8 MiB/2.6 MiB (14.7 MiB/s) with 1 file(s) remaining
# Completed 2.0 MiB/2.6 MiB (16.6 MiB/s) with 1 file(s) remaining
# Completed 2.2 MiB/2.6 MiB (18.0 MiB/s) with 1 file(s) remaining
# Completed 2.5 MiB/2.6 MiB (19.1 MiB/s) with 1 file(s) remaining
# ...

# %%
# !whoami
# Out:
# vbhargava

# %%
def s3_remove_files_recursive(
        config,
        s3_location,
        debug=False,
        print_stderr=False):
    """Executes a s3 cmd using aws s3 CLI, captures stdout into a pd.DataFrame
    and optionally prints stderr into the screen

    Parameters
    ---------
    df : pandas.DataFrame
        DataFrame to be uploaded to Hive
    config : string
        Path to `platform_config.xml` file for the client for which the table will be created
    debug : boolean (Optional)
        If True, prints debug info to stdout, default: False
    print_stderr : boolean (Optional)
        If True, prints stderr into screen, default: False
    **kwargs will be directly passed to hive_query()
    """
    #assert isinstance(df, pd.DataFrame), "df must be a pandas.DataFrame"
    assert isinstance(debug, bool), "debug must be boolean"
    assert isinstance(print_stderr, bool), "print_stderr must be boolean"

    # Parse config file
    platform, config_values = parse_config(config)
    print(config_values)
    assert platform.lower() in ('emr', 'qubole'), "Only EMR or Qubole platforms accepted"

    os.environ['AWS_ACCESS_KEY_ID'] = config_values['access_key']
    os.environ['AWS_SECRET_ACCESS_KEY'] = config_values['secret_key']
    
    if s3_location is None:
        return
    remove_dir_cmd = f"aws s3 rm {s3_location} --recursive"
    
    p = subprocess.Popen(
        remove_dir_cmd,
        shell=True,
        executable='/bin/bash',
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        universal_newlines=True,
        encoding='utf-8'
    )
    print("stdout:\n" + p.stdout.read())
    print("stderr:\n" + p.stderr.read())

# %%
s3_remove_files_recursive(config, "s3://qubole-nightly/warehouse/ctam_v81_testing/tpre_results")
# Out:
# {'s3_location': 's3://qubole-nightly/warehouse/', 'token': 'e1b02a0b8d5443c1aafba175312842f6bd833247361048438f37df2cedd51943', 'url': 'https://api.qubole.com/api', 'cluster': 'Nightly-Dnow', 'access_key': 'AKIAJSZT7LGTGV4UYU7Q', 'secret_key': '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'}
# stdout:
# delete: s3://qubole-nightly/warehouse/ctam_v81_testing/tpre_results/membership/2019-03-30-848478348835361-128900881029137-cohort_membership_100.csv
# Completed 1 file(s) with 9 file(s) remaining
# delete: s3://qubole-nightly/warehouse/ctam_v81_testing/tpre_results/request_id_mapping/request_id_mapping_7150_140515238819648_.csv.gz
# Completed 2 file(s) with 8 file(s) remaining
# delete: s3://qubole-nightly/warehouse/ctam_v81_testing/tpre_results/request_id_mapping/request_id_mapping_14946_140582126884672_.csv.gz
# Completed 3 file(s) with 7 file(s) remaining
# ...

# %%
access_token = args.access_token
account_id = args.account_id
pixel_id = args.pixel_id
business_id = args.business_id
table = args.table
set_name = args.set_name
description = args.description
event_set_id =  args.event_set_id
start_date = args.start_date
end_date = args.end_date
tag = args.tag_suffix 
config = args.config 
upload_file_path = args.path
dry_run =args.dry_run
report_destpath = args.destpath
client_warehouse_path = args.client_warehouse_path
